# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Omid Kheiri**<br/>
# Data Analysor

# %% [markdown]
# _I am interested in data science because it is fast grows in IT Domain_

# %% [markdown]
# ### Nex Line suppose to print sum of 1+1 in python

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# *** horizantal rule
# - one
# - two
#
# 1. One
# 2. two
#
# |header1|header2|
# |-|-|
# |cel1|cel2|
#
#
# <a href="http://IBM.COM">IBM.COM</a>
#
#
# <img src="https://jupyter-notebook.readthedocs.io/en/stable/_images/python_logo.svg" />
#
#
# ``` Python
# print(1+1);
# ```
# <blockquote>This is a  block quote</blockquote>
# <strike>strike through</strike>
